# %%
#!/usr/bin/env Rscript
args = commandArgs(trailingOnly=TRUE)

options(warn=-1)
library(Seurat)
# Out:
# Loading required package: ggplot2
# Loading required package: cowplot
#
# Attaching package: ‘cowplot’
#
# The following object is masked from ‘package:ggplot2’:
#
#     ggsave
#
# Loading required package: Matrix

# %%
args = c("/home/jupyter/Notebooks/KIRC/HSIEH/data/", "test.csv")

# %%
raw_data <- Read10X(data.dir = args[1])

# %%
# Out:
#               AAACCTGCACAGACTT AAACCTGCAGGTGGAT AAACCTGGTAAATACG
# DDX11L1       0                0                0
# WASH7P        0                0                0
# MIR6859-1     0                0                0
# RP11-34P13.3  0                0                0
# MIR1302-2     0                0                0
# FAM138A       0                0                0
# OR4G4P        0                0                0
# OR4G11P       0                0                0
# OR4F5         0                0                0
# RP11-34P13.7  0                0                0
# RP11-34P13.8  0                0                0
# CICP27        0                0                0
# RP11-34P13.15 0                0                0
# RP11-34P13.16 0                0                0
# RP11-34P13.14 0                0                0
# RP11-34P13.13 0                0                0
# RNU6-1100P    0                0                0
# ...

# %%
write.csv(as.data.frame(as.matrix(raw_data)), file=args[2])
